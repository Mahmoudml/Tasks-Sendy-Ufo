# %%
import numpy as np

# %%
import pandas as pd

# %%
sendy = pd.read_csv("C:\\Users\\go\\Downloads\\sendy_logistics.csv")

# %%
sendy.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %%
sum(sendy['Temperature'].isna())
# Out:
# 4366

# %%
sendy['Temperature'].fillna(value=sendy['Temperature'].mean(),inplace=True)

# %%
sum(sendy['Temperature'].isna())
# Out:
# 0

# %%
sendy["Temperature"].dropna(axis=0, inplace=True)

# %%
sendy['new_temp']=sendy['Temperature'] - 40

# %%
sendy["difference"]=sendy["Temperature"] * 9/5 + 32

# %%
sendy.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %%
sendy['difference'].mean()
# Out:
# 73.86600059400568

# %%
sendy['difference'].fillna(value=sendy['difference'].mean(),inplace = True)
sum(sendy['difference'].isna())
# Out:
# 0

# %%
sendy.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %%
sendy.describe()
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count   21201.000000              21201.000000                  21201.000000
# mean        2.752182                 15.653696                      3.240083
# std         0.625178                  8.798916                      1.567295
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                 21201.000000                     21201.000000
# mean                     15.653837                         3.240225
# std                       8.798886                         1.567228
# ...

# %%
sendy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21201 entries, 0 to 21200
# Data columns (total 31 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Order No                                   21201 non-null  object
#  1   User Id                                    21201 non-null  object
#  2   Vehicle Type                               21201 non-null  object
#  3   Platform Type                              21201 non-null  int64
#  4   Personal or Business                       21201 non-null  object
#  5   Placement - Day of Month                   21201 non-null  int64
#  6   Placement - Weekday (Mo = 1)               21201 non-null  int64
#  7   Placement - Time                           21201 non-null  object
#  8   Confirmation - Day of Month                21201 non-null  int64
#  9   Confirmation - Weekday (Mo = 1)            21201 non-null  int64
# ...

# %%
uf= pd.read_csv("C:\\Users\\go\\Downloads\\ufo.csv")

# %%
uf.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
uf["Time"].apply(lambda x: x.split('/')[0])
# Out:
# 0         6
# 1         6
# 2         2
# 3         6
# 4         4
#          ..
# 18236    12
# 18237    12
# 18238    12
# 18239    12
# 18240    12
# Name: Time, Length: 18241, dtype: object

# %%
uf['Time'].apply(lambda x: x.split('/')[0]=='12')
sum(uf['Time'].apply(lambda x: x.split('/')[0]=='12'))
# Out:
# 1034

# %%
uf['Time'] != 12
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 18236    True
# 18237    True
# 18238    True
# 18239    True
# 18240    True
# Name: Time, Length: 18241, dtype: bool

# %%
sum(uf["Time"] != 12)
# Out:
# 18241
